# %% [markdown]
# # 1. Import Dependencies

# %%
import cv2
import os

# %% [markdown]
# # 2. Read in Image

# %%
img_path = os.path.join('philo.jpg')

# %%
img = cv2.imread(img_path)

# %% [markdown]
# # 3. Render Image

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in ./.conda/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/lib/python3.11/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in ./.conda/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/lib/python3.11/site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.conda/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in ./.conda/lib/python3.11/site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in ./.conda/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./.conda/lib/python3.11/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in ./.conda/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from matplotlib import pyplot as plt

# %%
# Show image
plt.imshow(img)

# %%
recolor = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(recolor)
plt.show()

# %% [markdown]
# # 4. Write out Image

# %%
cv2.imwrite('grayimage.jpg', gray)
# Out:
# True

# %%
output_path = os.path.join('outputgray.jpg')

# %%
cv2.imwrite(output_path, gray)
# Out:
# True
